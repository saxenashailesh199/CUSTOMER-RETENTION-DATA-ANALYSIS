# %% [raw]
# E-retail factors for customer activation and retention: A case study from Indian e-commerce customers
#
# Customer satisfaction has emerged as one of the most important factors that guarantee the success of online store; it has been posited as a key stimulant of purchase, repurchase intentions and customer loyalty. A comprehensive review of the literature, theories and models have been carried out to propose the models for customer activation and customer retention. Five major factors that contributed to the success of an e-commerce store have been identified as: service quality, system quality, information quality, trust and net benefit. The research furthermore investigated the factors that influence the online customers repeat purchase intention. The combination of both utilitarian value and hedonistic values are needed to affect the repeat purchase intention (loyalty) positively. The data is collected from the Indian online shoppers. Results indicate the e-retail success factors, which are very much critical for customer satisfaction.
#
# Be careful: There are two sheets (one is detailed) and second is encoded in the excel file. You may use any of them by extracting in separate excel sheet. The number of column(s) is more than 47. Read the column header carefully.
#
# Note : Data Scientists have to apply their analytical skills to give findings and conclusions in detailed data analysis written in jupyter notebook . Only data analysis is required.

# %% [markdown]
# # IMPORT THE LIBRARIES

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline

# %% [markdown]
# # DATA INPUT

# %%
df = pd.read_excel('customer_retention_dataset.xlsx')

# %%
pd.set_option("display.max_column",2000)

# %%
pd.set_option("display.max_row",2000)

# %%
df.head()
# Out:
#   1Gender of respondent 2 How old are you?   \
# 0                  Male         31-40 years
# 1                Female         21-30 years
# 2                Female         21-30 years
# 3                  Male         21-30 years
# 4                Female         21-30 years
#
#   3 Which city do you shop online from?  \
# 0                                 Delhi
# 1                                 Delhi
# 2                         Greater Noida
# 3                               Karnal
# 4                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# ...

# %% [markdown]
# # PREPROCESSING OF DATA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 269 entries, 0 to 268
# Data columns (total 71 columns):
#  #   Column                                                                                                                                                                                                          Non-Null Count  Dtype
# ---  ------                                                                                                                                                                                                          --------------  -----
#  0   1Gender of respondent                                                                                                                                                                                           269 non-null    object
# ...

# %%
print("No. of rows = ", df.shape[0])
print("No. of columns = ", df.shape[1])
# Out:
# No. of rows =  269
# No. of columns =  71

# %%
print("Number of empty rows = ", df.isnull().all(axis =1).sum())
# Out:
# Number of empty rows =  0

# %%
print("Number of empty columns = ", df.isnull().all(axis =0).sum())
# Out:
# Number of empty columns =  0

# %%
df.shape
# Out:
# (269, 71)

# %%
df.columns
# Out:
# Index(['1Gender of respondent', '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...

# %%
df.select_dtypes(include=['int64','float64']).head()
# Out:
#    4 What is the Pin Code of where you shop online from?
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068

# %%
df.select_dtypes(include=['int64','float64']).head().columns
# Out:
# Index(['4 What is the Pin Code of where you shop online from?'], dtype='object')

# %% [markdown]
# # HEDONIC VALUE

# %% [markdown]
# Gratification, Role, Best Deal, Social, Adventure

# %% [raw]
#        '1Gender of respondent',
#        '2 How old are you? ',
#        '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
#        '13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ',
#        '14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ',
#        '15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ',
#        '16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ',
#        '17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ',
#        '18 The content on the website must be easy to read and understand',
#        '19 Information on similar product to the one highlighted  is important for product comparison',
#        '20 Complete information on listed seller and product being offered is important for purchase decision.',
#        '21 All relevant information on listed products must be stated clearly',
#        '22 Ease of navigation in website',
#        '23 Loading and processing speed',
#        '24 User friendly Interface of the website',
#        '25 Convenient Payment methods',
#        '26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',
#        '27 Empathy (readiness to assist with queries) towards the customers',
#        '28 Being able to guarantee the privacy of the customer',
#        '29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',
#        '30 Online shopping gives monetary benefit and discounts',
#        '31 Enjoyment is derived from shopping online',
#        '32 Shopping online is convenient and flexible',
#        '33 Return and replacement policy of the e-tailer is important for purchase decision',
#        '34 Gaining access to loyalty programs is a benefit of shopping online',
#        '35 Displaying quality Information on the website improves satisfaction of customers',
#        '36 User derive satisfaction while shopping on a good quality website or application',
#        '37 Net Benefit derived from shopping online can lead to users satisfaction',
#        '38 User satisfaction cannot exist without trust',
#        '39 Offering a wide variety of listed product in several category',
#        '40 Provision of complete and relevant product information',
#        '41 Monetary savings',
#        '42 The Convenience of patronizing the online retailer',
#        '43 Shopping on the website gives you the sense of adventure',
#        '44 Shopping on your preferred e-tailer enhances your social status',
#        '45 You feel gratification shopping on your favorite e-tailer',
#        '46 Shopping on the website helps you fulfill certain roles',
#        '47 Getting value for money spent',
#        'From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ',
#        'Easy to use website or application',
#        'Visual appealing web-page layout', 'Wild variety of product on offer',
#        'Complete, relevant description information of products',
#        'Fast loading website speed of website and application',
#        'Reliability of the website or application',

# %% [markdown]
# # UTILITARIAN VALUE

# %% [markdown]
# Product Offering, Convenience, Product Information, Monetary Saving

# %%
       'Quickness to complete purchase',
       'Availability of several payment options', 'Speedy order delivery ',
       'Privacy of customers’ information',
       'Security of customer financial information',
       'Perceived Trustworthiness',
       'Presence of online assistance through multi-channel',
       'Longer time to get logged in (promotion, sales period)',
       'Longer time in displaying graphics and photos (promotion, sales period)',
       'Late declaration of price (promotion, sales period)',
       'Longer page loading time (promotion, sales period)',
       'Limited mode of payment on most products (promotion, sales period)',
       'Longer delivery period', 'Change in website/Application design',
       'Frequent disruption when moving from one page to another',
       'Website is as efficient as before',
       'Which of the Indian online retailer would you recommend to a friend?'

# %% [markdown]
# # EDA ANALYSIS

# %%
df.nunique()
# Out:
# 1Gender of respondent                                                                                                                                                                                                   2
# 2 How old are you?                                                                                                                                                                                                      5
# 3 Which city do you shop online from?                                                                                                                                                                                  11
# 4 What is the Pin Code of where you shop online from?                                                                                                                                                                  39
# ...

# %%
df[''].value_counts()

# %% [markdown]
# # 1 COLUMN

# %%
1Gender of respondent

# %%
df['1Gender of respondent'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['1Gender of respondent'].value_counts()
# Out:
# Female    181
# Male       88
# Name: 1Gender of respondent, dtype: int64

# %%
sns.countplot(x='1Gender of respondent',data=df)

# %% [markdown]
# # It says that online shopping are mostly preferred by females

# %% [markdown]
# # 2 COLUMN

# %%
df['2 How old are you? '].unique()
# Out:
# array(['31-40 years', '21-30 years', '41-50 yaers', 'Less than 20 years',
#        '51 years and above'], dtype=object)

# %%
df['2 How old are you? '].value_counts()
# Out:
# 31-40 years           81
# 21-30 years           79
# 41-50 yaers           70
# Less than 20 years    20
# 51 years and above    19
# Name: 2 How old are you? , dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='2 How old are you? ',data=df)

# %% [markdown]
# # It says that people having age more than 20 and less than 50 prefer online shopping

# %%
plt.figure(figsize=(15,25))     #(column,row)
sns.catplot(x='4 What is the Pin Code of where you shop online from?',y='1Gender of respondent',data=df)

# %% [markdown]
# # 3 COLUMN

# %%
df['3 Which city do you shop online from?'].value_counts()
# Out:
# Delhi            58
# Greater Noida    43
# Noida            40
# Bangalore        37
# Karnal           27
# Solan            18
# Ghaziabad        18
# Gurgaon          12
# Merrut            9
# Moradabad         5
# Bulandshahr       2
# Name: 3 Which city do you shop online from?, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='3 Which city do you shop online from?',data=df)

# %%
sns.barplot(x='1Gender of respondent_Female',y='3 Which city do you shop online from?',data=df_final)

# %% [markdown]
# # 4 COLUMN

# %%
df['4 What is the Pin Code of where you shop online from?'].value_counts()
# Out:
# 201308    38
# 132001    19
# 201310    18
# 110044    16
# 173212     9
# 250001     9
# 173229     9
# 560037     8
# 132036     8
# 560010     8
# 122018     8
# 110011     7
# 201306     7
# 110008     7
# 110014     6
# 110018     6
# 244001     5
# 201312     5
# 530068     5
# 201305     5
# 201009     5
# 201008     5
# 201005     4
# 201001     4
# 201304     4
# 110039     4
# 110030     4
# 110009     4
# 560018     4
# 560003     4
# 122009     4
# 560002     4
# 110042     4
# 201303     4
# 560013     3
# 203001     2
# 560001     1
# 203207     1
# 203202     1
# Name: 4 What is the Pin Code of where you shop online from?, dtype: int64

# %% [markdown]
# # 5 COLUMN

# %%
df['5 Since How Long You are Shopping Online ?'].value_counts()
# Out:
# Above 4 years       98
# 2-3 years           65
# 3-4 years           47
# Less than 1 year    43
# 1-2 years           16
# Name: 5 Since How Long You are Shopping Online ?, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='5 Since How Long You are Shopping Online ?',data=df)

# %% [markdown]
# # Mostly people are shopping from more than 4 years

# %% [markdown]
# # 6 COLUMN

# %%
df['6 How many times you have made an online purchase in the past 1 year?'].value_counts()
# Out:
# Less than 10 times    114
# 31-40 times            63
# 41 times and above     47
# 11-20 times            29
# 21-30 times            10
# 42 times and above      6
# Name: 6 How many times you have made an online purchase in the past 1 year?, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='6 How many times you have made an online purchase in the past 1 year?',data=df)

# %%
There are majority of people which made less than 10 purchases in a year

# %% [markdown]
# # 7 COLUMN

# %%
df['7 How do you access the internet while shopping on-line?'].value_counts()
# Out:
# Mobile internet    142
# Wi-Fi               76
# Mobile Internet     47
# Dial-up              4
# Name: 7 How do you access the internet while shopping on-line?, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='7 How do you access the internet while shopping on-line?',data=df)

# %% [markdown]
# # It tell us that people highly uses mobile internet for online shopping

# %% [markdown]
# # 8 COLUMN

# %%
df['8 Which device do you use to access the online shopping?'].value_counts()
# Out:
# Smartphone    141
# Laptop         86
# Desktop        30
# Tablet         12
# Name: 8 Which device do you use to access the online shopping?, dtype: int64

# %%
plt.figubre(figsize=(15,5))     #(column,row)
sns.countplot(x='8 Which device do you use to access the online shopping?',data=df)

# %% [markdown]
# # Mostly smartphone are used for online shopping

# %% [markdown]
# # 9 COLUMN

# %%
df['9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        '].value_counts()
# Out:
# Others        134
# 5.5 inches     99
# 4.7 inches     29
# 5 inches        7
# Name: 9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        , dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',data=df)

# %% [markdown]
# # MAXIMUM PEOPLE PREFER MOBILES OF Larger screen sizes

# %% [markdown]
# # 10 COLUMN

# %%
df['10 What is the operating system (OS) of your device?\t\t\t\t                                          '].value_counts()
# Out:
# Window/windows Mobile    122
# Android                   85
# IOS/Mac                   62
# Name: 10 What is the operating system (OS) of your device?\t\t\t\t                                          , dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='10 What is the operating system (OS) of your device?\t\t\t\t                                          ',data=df)

# %% [markdown]
# # MAXIMUM PERSOM USES WINDOWS OPERATING SYSTEM

# %% [markdown]
# # 11 COLUMN

# %%
df['11 What browser do you run on your device to access the website?\t\t\t                                                          '].value_counts()
# Out:
# Google chrome      216
# Safari              40
# Opera                8
# Mozilla Firefox      5
# Name: 11 What browser do you run on your device to access the website?\t\t\t                                                          , dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='11 What browser do you run on your device to access the website?\t\t\t                                                          ',data=df)

# %% [markdown]
# # ALMOST EVERYONE USES GOOGLE CROME BROWSER

# %% [markdown]
# # 12 COLUMN

# %%
df['12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   '].value_counts()
# Out:
# Search Engine        230
# Content Marketing     20
# Display Adverts       19
# Name: 12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   , dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',data=df)

# %% [markdown]
# # PEOPLE FOLLOW THE WEBSITES THROUGH SEARCH ENGINE

# %% [markdown]
# # 13 COLUMN

# %%
df['13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   '].value_counts()
# Out:
# Search Engine      87
# Via application    86
# Direct URL         70
# E-mail             18
# Social Media        8
# Name: 13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   , dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='13 After first visit, how do you reach the online retail store?\t\t\t\t                                                   ',data=df)

# %% [markdown]
# # After first visit, people reach the online retail store different medium like search engine,application and direct url. Least preferrence medium are e-mail and social media.

# %% [markdown]
# # 14 COLUMN

# %%
df['14 How much time do you explore the e- retail store before making a purchase decision?                                                                   '].value_counts()
# Out:
# more than 15 mins    123
# 6-10 mins             71
# 11-15 mins            46
# Less than 1 min       15
# 1-5 mins              14
# Name: 14 How much time do you explore the e- retail store before making a purchase decision?                                                                   , dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='14 How much time do you explore the e- retail store before making a purchase decision?                                                                   ',data=df)

# %% [markdown]
# # PEOPLE USUALLY EXPLORE MORE THAN 15 MINUTES BEFORE MAKING A PURCHASE

# %% [markdown]
# # 15 COLUMN

# %%
df['15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               '].value_counts()
# Out:
# Credit/Debit cards                    148
# Cash on delivery (CoD)                 76
# E-wallets (Paytm, Freecharge etc.)     45
# Name: 15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               , dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='15 What is your preferred payment Option?\t\t\t\t\t                                                                                                                               ',data=df)

# %% [markdown]
# # CUSTOMER USUALLY PREFER CREDIT/DEBIT CARD FOR PAYMENT OPTION.

# %% [markdown]
# # 16 COLUMN

# %%
df['16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   '].value_counts()
# Out:
# Sometimes          171
# Never               48
# Frequently          35
# Very frequently     15
# Name: 16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   , dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='16 How frequently do you abandon (selecting an items and leaving without making payment) your shopping cart?\t\t\t\t\t\t\t                                                   ',data=df)

# %% [markdown]
# # SOMETIMES CUSTOMER ABANDON THE SHOPPING CART.

# %% [markdown]
# # 17 COLUMN

# %%
df['17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       '].value_counts()
# Out:
# Better alternative offer        133
# Promo code not applicable        54
# Change in price                  37
# Lack of trust                    31
# No preferred mode of payment     14
# Name: 17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       , dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='17 Why did you abandon the “Bag”, “Shopping Cart”?\t\t\t\t\t                                                                                                                                                       ',data=df)

# %% [markdown]
# # THEY ABANDON THE SHOPPING CART BECAUSE THE GET THE BEST ALTERNATIVE OFFER FOR THE PRODUCT THEY WAT TO PURCHASE

# %% [markdown]
# # 18 COLUMN

# %%
df['18 The content on the website must be easy to read and understand'].value_counts()
# Out:
# Strongly agree (5)       164
# Agree (4)                 80
# Strongly disagree (1)     18
# Indifferent (3)            7
# Name: 18 The content on the website must be easy to read and understand, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='18 The content on the website must be easy to read and understand',data=df)

# %% [markdown]
# # ALMOST ALL THE CUSTOMER SAYS THAT THEY AGREE ON THE FACT THAT CONTENT ON THE WEBSITE MUST BE EASY TO READ AND UNDERSTAND

# %% [markdown]
# # 19 COLUMN

# %%
df['19 Information on similar product to the one highlighted  is important for product comparison'].value_counts()
# Out:
# Strongly agree (5)    116
# Agree (4)              92
# Indifferent (3)        43
# Dis-agree (2)          18
# Name: 19 Information on similar product to the one highlighted  is important for product comparison, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='19 Information on similar product to the one highlighted  is important for product comparison',data=df)

# %% [markdown]
# # MAJORITY OF CUSTOMER AGREE ON THE TERM THAT INFORMATION ON SIMILAR PRODUCT TO THE ONE HIGHLIGHTED IS IMPORTANT FOR PRODUCT COMPARISON

# %% [markdown]
# # 20 COLUMN

# %%
df['20 Complete information on listed seller and product being offered is important for purchase decision.'].value_counts()
# Out:
# Agree (4)                101
# Strongly agree (5)        87
# Indifferent (3)           52
# Dis-agree (2)             18
# Strongly disagree (1)     11
# Name: 20 Complete information on listed seller and product being offered is important for purchase decision., dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='20 Complete information on listed seller and product being offered is important for purchase decision.',data=df)

# %% [markdown]
# # MOSTLY CUSTOMER ARE AGREE ON THE FACT THAT COMPLETE INFORMATION ON LISTED SELLER AND PRODUCT BEING OFFERED IS IMPORTANT FOR PURCHASE DECISION.

# %% [markdown]
# # 21 COLUMN

# %%
df['21 All relevant information on listed products must be stated clearly'].value_counts()
# Out:
# Agree (4)                132
# Strongly agree (5)       107
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Name: 21 All relevant information on listed products must be stated clearly, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='21 All relevant information on listed products must be stated clearly',data=df)

# %% [markdown]
# # ALLMOST ALL THE CUSTOMER AGREE ON THE FACT THAT All relevant information on listed products must be stated clearly.

# %% [markdown]
# # 22 COLUMN

# %%
df['22 Ease of navigation in website'].value_counts()
# Out:
# Strongly agree (5)       141
# Agree (4)                105
# Strongly disagree (1)     18
# Dis-agree (2)              5
# Name: 22 Ease of navigation in website, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='22 Ease of navigation in website',data=df)

# %% [markdown]
# # MORE THAN 90% OF THE CUSTOMER ARE AGREE THAT THERE IS Ease of navigation in website.

# %% [markdown]
# # 23 COLUMN

# %%
df['23 Loading and processing speed'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                112
# Dis-agree (2)             18
# Indifferent (3)           12
# Strongly disagree (1)     12
# Name: 23 Loading and processing speed, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='23 Loading and processing speed',data=df)

# %% [markdown]
# # 24 COLUMN

# %%
df['24 User friendly Interface of the website'].value_counts()
# Out:
# Strongly agree (5)       189
# Agree (4)                 45
# Strongly disagree (1)     18
# Dis-agree (2)             12
# Indifferent (3)            5
# Name: 24 User friendly Interface of the website, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='24 User friendly Interface of the website',data=df)

# %% [markdown]
# # ABOUT MORE THAN 90% CUSTOMER AGREE ON THE FACT THEY APPRRECIATE A User friendly Interface of the website.

# %% [markdown]
# # 25 COLUMN

# %%
df['25 Convenient Payment methods'].value_counts()
# Out:
# Strongly agree (5)    159
# Agree (4)              80
# Dis-agree (2)          30
# Name: 25 Convenient Payment methods, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='25 Convenient Payment methods',data=df)

# %% [markdown]
# # MORE THAN 90% OF CUSTOMER AGREE ON THE FACT THAT THER SHOULD BE Convenient Payment methods

# %% [markdown]
# # 26 COLUMN

# %%
df['26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time'].value_counts()
# Out:
# Strongly agree (5)    141
# Agree (4)              86
# Disagree (2)           30
# indifferent  (3)       12
# Name: 26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='26 Trust that the online retail store will fulfill its part of the transaction at the stipulated time',data=df)

# %% [markdown]
# # ABOUT 90% CUSTOMER Trust that the online retail store will fulfill its part of the transaction at the stipulated time.

# %% [markdown]
# # 27 COLUMN

# %%
df['27 Empathy (readiness to assist with queries) towards the customers'].value_counts()
# Out:
# Strongly agree (5)       194
# Agree (4)                 42
# Strongly disagree (1)     18
# indifferent (3)           15
# Name: 27 Empathy (readiness to assist with queries) towards the customers, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='27 Empathy (readiness to assist with queries) towards the customers',data=df)

# %% [markdown]
# # MORE THAN 95% CUSTOMER ARE AGREE ON THE FACT THAT THERE IS Empathy (readiness to assist with queries) towards the customers.

# %% [markdown]
# # 28 COLUMN

# %%
df['28 Being able to guarantee the privacy of the customer'].value_counts()
# Out:
# Strongly agree (5)    185
# Agree (4)              58
# indifferent (3)        26
# Name: 28 Being able to guarantee the privacy of the customer, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='28 Being able to guarantee the privacy of the customer',data=df)

# %% [markdown]
# # MORE THAN 95% CUSTOMER ARE Being able to guarantee the privacy of the customer.

# %% [markdown]
# # 29 COLUMN

# %%
df['29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)'].value_counts()
# Out:
# Strongly agree (5)       149
# Agree (4)                 94
# indifferent (3)           15
# Strongly disagree (1)     11
# Name: 29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.), dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='29 Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)',data=df)

# %% [markdown]
# # MORE THAN 95% CUSTOMER ARE AGREE ON THE Responsiveness, availability of several communication channels (email, online rep, twitter, phone etc.)

# %% [markdown]
# # 30 COLUMN

# %%
df['30 Online shopping gives monetary benefit and discounts'].value_counts()
# Out:
# Strongly agree (5)       105
# Agree (4)                 85
# indifferent (3)           50
# Strongly disagree (1)     18
# Dis-agree (2)             11
# Name: 30 Online shopping gives monetary benefit and discounts, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='30 Online shopping gives monetary benefit and discounts',data=df)

# %% [markdown]
# # ABOUT 80% CUTOMER SAY'S THAT Online shopping gives monetary benefit and discounts.

# %% [markdown]
# # 31 COLUMN

# %%
df['31 Enjoyment is derived from shopping online'].value_counts()
# Out:
# Strongly agree (5)       86
# indifferent (3)          75
# Agree (4)                59
# Strongly disagree (1)    30
# Dis-agree (2)            19
# Name: 31 Enjoyment is derived from shopping online, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='31 Enjoyment is derived from shopping online',data=df)

# %% [markdown]
# # THERE IS CONTRAIDCTION IN VIEWS ON  Enjoyment is derived from shopping online.SOME ARRE AGREE AND SMOE ARE NOT.

# %% [markdown]
# # 32 COLUMN

# %%
df['32 Shopping online is convenient and flexible'].value_counts()
# Out:
# Strongly agree (5)    146
# Agree (4)              78
# indifferent (3)        33
# Dis-agree (2)          12
# Name: 32 Shopping online is convenient and flexible, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='32 Shopping online is convenient and flexible',data=df)

# %% [markdown]
# # MORE THAN 90% CUSTOMER ARE AGREE ON THE FACT THAT Shopping online is convenient and flexible.

# %% [markdown]
# # 33 COLUMN

# %%
df['33 Return and replacement policy of the e-tailer is important for purchase decision'].value_counts()
# Out:
# Strongly agree (5)    198
# Agree (4)              51
# Dis-agree (2)          20
# Name: 33 Return and replacement policy of the e-tailer is important for purchase decision, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='33 Return and replacement policy of the e-tailer is important for purchase decision',data=df)

# %% [markdown]
# # MORE THAN 90% CUSTOMER ARE AGREE ON THT FACT THAT Return and replacement policy of the e-tailer is important for purchase decision.

# %% [markdown]
# # 34 COLUMN

# %%
df['34 Gaining access to loyalty programs is a benefit of shopping online'].value_counts()
# Out:
# Strongly agree (5)       115
# Agree (4)                 64
# indifferent (3)           64
# Dis-agree (2)             15
# Strongly disagree (1)     11
# Name: 34 Gaining access to loyalty programs is a benefit of shopping online, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='34 Gaining access to loyalty programs is a benefit of shopping online',data=df)

# %% [markdown]
# # 35 COLUMN

# %%
df['35 Displaying quality Information on the website improves satisfaction of customers'].value_counts()
# Out:
# Strongly agree (5)    133
# Agree (4)              80
# indifferent (3)        56
# Name: 35 Displaying quality Information on the website improves satisfaction of customers, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='35 Displaying quality Information on the website improves satisfaction of customers',data=df)

# %% [markdown]
# # ABOUT 70% CUSTOMERS AGREE ON THE FACT THAT Displaying quality Information on the website improves satisfaction of customers.

# %% [markdown]
# # 36 COLUMN

# %%
df['36 User derive satisfaction while shopping on a good quality website or application'].value_counts()
# Out:
# Strongly agree (5)    175
# Agree (4)              86
# Dis-agree (2)           8
# Name: 36 User derive satisfaction while shopping on a good quality website or application, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='36 User derive satisfaction while shopping on a good quality website or application',data=df)

# %% [markdown]
# # ABOUT 99% CUSTOMERS ARE AGREE ON THE FACT THAT User derive satisfaction while shopping on a good quality website or application.

# %% [markdown]
# # 37 COLUMN

# %%
df['37 Net Benefit derived from shopping online can lead to users satisfaction'].value_counts()
# Out:
# Strongly agree (5)    164
# Agree (4)              54
# indifferent (3)        40
# Dis-agree (2)          11
# Name: 37 Net Benefit derived from shopping online can lead to users satisfaction, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='37 Net Benefit derived from shopping online can lead to users satisfaction',data=df)

# %% [markdown]
# # ABOUT 90% CUSTOMERS AGREE ON THE FACT THAT Net Benefit derived from shopping online can lead to users satisfaction.

# %% [markdown]
# # 38 COLUMN

# %%
df['38 User satisfaction cannot exist without trust'].value_counts()
# Out:
# Strongly agree (5)       122
# Agree (4)                117
# Strongly disagree (1)     18
# Dis-agree (2)              7
# indifferent (3)            5
# Name: 38 User satisfaction cannot exist without trust, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='38 User satisfaction cannot exist without trust',data=df)

# %% [markdown]
# # MORE THAN 95% CUSTOMERS SAYS THAT User satisfaction cannot exist without trust.

# %% [markdown]
# # 39 COLUMN

# %%
df['39 Offering a wide variety of listed product in several category'].value_counts()
# Out:
# Strongly agree (5)    111
# Agree (4)              94
# indifferent (3)        57
# Dis-agree (2)           7
# Name: 39 Offering a wide variety of listed product in several category, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='39 Offering a wide variety of listed product in several category',data=df)

# %% [markdown]
# # MORE THAN 80% CUSTOMER SAYS YES THAT ONLINE SHOPPING Offering a wide variety of listed product in several category.

# %% [markdown]
# # 40 COLUMN

# %%
df['40 Provision of complete and relevant product information'].value_counts()
# Out:
# Strongly agree (5)    135
# Agree (4)              98
# indifferent (3)        31
# Disagree (2)            5
# Name: 40 Provision of complete and relevant product information, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='40 Provision of complete and relevant product information',data=df)

# %% [markdown]
# # MORE THAN 85% CUSTOMER SAYS THAT THERE SHOULD BE Provision of complete and relevant product information.

# %% [markdown]
# # 41 COLUMN

# %%
df['41 Monetary savings'].value_counts()
# Out:
# Strongly agree (5)    148
# Agree (4)              75
# Disagree (2)           31
# indifferent (3)        15
# Name: 41 Monetary savings, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='41 Monetary savings',data=df)

# %% [markdown]
# # MORE THAN 90% CUSTOMERS AGREE ON THE Monetary savings THROUGH ONLINE SHOPPING.

# %% [markdown]
# # 42 COLUMN

# %%
df['42 The Convenience of patronizing the online retailer'].value_counts()
# Out:
# Agree (4)             138
# indifferent (3)        77
# Strongly agree (5)     54
# Name: 42 The Convenience of patronizing the online retailer, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='42 The Convenience of patronizing the online retailer',data=df)

# %% [markdown]
# # MORE THAN 70% CUSTOMERS AGREE ON The Convenience of patronizing the online retailer.

# %% [markdown]
# # 43 COLUMN

# %%
df['43 Shopping on the website gives you the sense of adventure'].value_counts()
# Out:
# Agree (4)                101
# indifferent (3)           59
# Strongly agree (5)        54
# Dis-agree (2)             50
# Strongly disagree (1)      5
# Name: 43 Shopping on the website gives you the sense of adventure, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='43 Shopping on the website gives you the sense of adventure',data=df)

# %% [markdown]
# # ABOUT MORE THAN 60% CUSTOMER SAYS THAT Shopping on the website gives you the sense of adventure.

# %% [markdown]
# # 44 COLUMN

# %%
df['44 Shopping on your preferred e-tailer enhances your social status'].value_counts()
# Out:
# indifferent (3)          100
# Agree (4)                 59
# Strongly agree (5)        48
# Strongly disagree (1)     33
# Dis-agree (2)             29
# Name: 44 Shopping on your preferred e-tailer enhances your social status, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='44 Shopping on your preferred e-tailer enhances your social status',data=df)

# %% [markdown]
# # THERE IS INDIFFERENT VIEWS ON Shopping on your preferred e-tailer enhances your social status.

# %% [markdown]
# # 45 COLUMN

# %%
df['45 You feel gratification shopping on your favorite e-tailer'].value_counts()
# Out:
# indifferent (3)          101
# Strongly agree (5)        65
# Agree (4)                 63
# Disagree (2)              22
# Strongly disagree (1)     18
# Name: 45 You feel gratification shopping on your favorite e-tailer, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='45 You feel gratification shopping on your favorite e-tailer',data=df)

# %% [markdown]
# # THERE IS MAXIMUM INDIFFERENT VIEWS ON You feel gratification shopping on your favorite e-tailer.

# %% [markdown]
# # 46 COLUMN

# %%
df['46 Shopping on the website helps you fulfill certain roles'].value_counts()
# Out:
# Agree (4)                88
# indifferent (3)          88
# Strongly agree (5)       38
# Strongly disagree (1)    33
# Dis-agree (2)            22
# Name: 46 Shopping on the website helps you fulfill certain roles, dtype: int64

# %%
plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='46 Shopping on the website helps you fulfill certain roles',data=df)

# %% [markdown]
# # THIS FACT IS DISPUTED THAT Shopping on the website helps you fulfill certain roles.

# %% [markdown]
# # 47 COLUMN

# %%
df['47 Getting value for money spent'].value_counts()
# Out:
# Agree (4)             149
# Strongly agree (5)     82
# indifferent (3)        38
# Name: 47 Getting value for money spent, dtype: int64

# %%
#plt.figure(figsize=(15,5))     #(column,row)
sns.countplot(x='47 Getting value for money spent',data=df)

# %% [markdown]
# # ABOUT MORE THAN 90% CUSTOMERS SAYS  THAT THEY ARE GETTING value for money spent.

# %% [markdown]
# # 48 COLUMN

# %%
df['From the following, tick any (or all) of the online retailers you have shopped from;                                                                           '].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    82
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in, Flipkart.com                                         32
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                29
# Amazon.in, Flipkart.com, Snapdeal.com                           27
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in                                                       16
# Amazon.in, Paytm.com                                            12
# Amazon.in, Flipkart.com, Paytm.com                               7
# Name: From the following, tick any (or all) of the online retailers you have shopped from;                                                                           , dtype: int64

# %%
sns.countplot(y='From the following, tick any (or all) of the online retailers you have shopped from;                                                                           ',data=df)

# %% [markdown]
# # MAXIMUM CUSTOMER SHOPPED FROM AMAZON,FLIPKART, PAYTM,MYNTRA AND SNAPDEAL

# %% [markdown]
# # 49 COLUMN

# %%
df['Easy to use website or application'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    64
# Amazon.in, Flipkart.com                                         44
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               44
# Amazon.in                                                       29
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                22
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Flipkart.com, Myntra.com                             19
# Paytm.com                                                       12
# Flipkart.com                                                     8
# Amazon.in, Paytm.com                                             7
# Name: Easy to use website or application, dtype: int64

# %%
#plt.figure(figsize=(15,15))     #(column,row)
sns.countplot(y='Easy to use website or application',data=df)

# %% [markdown]
# # AMAZON AND FLIPKART IS THE Easy to use website or application.

# %% [markdown]
# # 50 COLUMN

# %%
df['Visual appealing web-page layout'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         87
# Amazon.in                                                       44
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    36
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Myntra.com                                           15
# Flipkart.com, Myntra.com                                        15
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Flipkart.com                                                    12
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com                11
# Name: Visual appealing web-page layout, dtype: int64

# %%
plt.figure(figsize=(15,15))     #(column,row)
sns.countplot(y='Visual appealing web-page layout',data=df)

# %% [markdown]
# # AMAZON AND FLIPKART IS HAVING THE BEST Visual appealing web-page layout.

# %% [markdown]
# # 51 COLUMN

# %%
df['Wild variety of product on offer'].value_counts()
# Out:
# Amazon.in, Flipkart.com                              130
# Amazon.in                                             43
# Amazon.in, Myntra.com                                 20
# Flipkart.com, Myntra.com                              15
# Myntra.com                                            15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com     14
# Amazon.in, Flipkart.com, Paytm.com                    13
# Flipkart.com                                          12
# Paytm.com                                              7
# Name: Wild variety of product on offer, dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Wild variety of product on offer',data=df)

# %% [markdown]
# # AMAZON AND FLIPKART IS HAVING Wild variety of product on offer.

# %% [markdown]
# # 52 COLUMN

# %%
df['Complete, relevant description information of products'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         100
# Amazon.in                                                        43
# Amazon.in, Flipkart.com, Paytm.com                               24
# Amazon.in, Paytm.com, Myntra.com                                 20
# Amazon.in, Flipkart.com, Myntra.com                              15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com     15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com                14
# Snapdeal.com                                                     12
# Flipkart.com, Snapdeal.com                                       11
# Flipkart.com                                                      8
# Amazon.in, Flipkart.com, Snapdeal.com                             7
# Name: Complete, relevant description information of products, dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Complete, relevant description information of products',data=df)

# %% [markdown]
# # AMAZON AND FLIPKART GIVES Complete, relevant description information of products.

# %% [markdown]
# # 53 COLUMN

# %%
df['Fast loading website speed of website and application'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Paytm.com                                            44
# Amazon.in, Flipkart.com                                         30
# Amazon.in, Flipkart.com, Myntra.com                             30
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    30
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com, Paytm.com                              25
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Snapdeal.com                                                    12
# Flipkart.com                                                     8
# Name: Fast loading website speed of website and application, dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Fast loading website speed of website and application',data=df)

# %% [markdown]
# # AMAZON is the best webiste acoording to Fast loading website speed of website and application.

# %% [markdown]
# # 54 COLUMN

# %%
df['Reliability of the website or application'].value_counts()
# Out:
# Amazon.in                                            61
# Amazon.in, Flipkart.com                              50
# Amazon.in, Flipkart.com, Paytm.com                   36
# Amazon.in, Paytm.com, Myntra.com                     35
# Amazon.in, Flipkart.com, Snapdeal.com                18
# Myntra.com                                           15
# Flipkart.com                                         15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com    14
# Amazon.in, Flipkart.com, Paytm.com, Snapdeal.com     13
# Paytm.com                                            12
# Name: Reliability of the website or application, dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Reliability of the website or application',data=df)

# %% [markdown]
# # According to customer data amazon and flipkart shows better Reliability of the website or application than others.

# %% [markdown]
# # 55 COLUMN

# %%
df['Quickness to complete purchase'].value_counts()
# Out:
# Amazon.com                                                   66
# Amazon.com, Flipkart.com, Paytm.com                          47
# Amazon.com, Flipkart.com                                     37
# Amazon.com, Flipkart.com, Myntra.com                         30
# Paytm.com                                                    25
# Amazon.com, Paytm.com, Myntra.com                            20
# Amazon.com, Flipkart.com, Paytm.com, Myntra.com, Snapdeal    15
# Flipkart.com                                                 15
# Flipkart.com, Myntra.com, Snapdeal                           14
# Name: Quickness to complete purchase, dtype: int64

# %%
# plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Quickness to complete purchase',data=df)

# %% [markdown]
# # THERE IS Quickness to complete purchase on Amazon,Flipkart and Myntra compared to others according to survey.

# %% [markdown]
# # 56 COLUMN

# %%
df['Availability of several payment options'].value_counts()
# Out:
# Amazon.in, Flipkart.com                                         65
# Amazon.in, Flipkart.com, Myntra.com                             40
# Amazon.in, Flipkart.com, Patym.com, Myntra.com, Snapdeal.com    39
# Amazon.in                                                       23
# Patym.com, Myntra.com                                           20
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               19
# Amazon.in, Flipkart.com, Snapdeal.com                           18
# Flipkart.com, Myntra.com, Snapdeal.com                          14
# Patym.com                                                       12
# Amazon.in, Patym.com                                            11
# Flipkart.com                                                     8
# Name: Availability of several payment options, dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Availability of several payment options',data=df)

# %% [markdown]
# # AMAZON AND FLIPKART ARE HAVING MAXIMUM Availability of several payment options COMPARED TO OTHERS.

# %% [markdown]
# # 57 COLUMN

# %%
df['Speedy order delivery '].value_counts()
# Out:
# Amazon.in                                 107
# Amazon.in, Flipkart.com                    82
# Amazon.in, Flipkart.com, Snapdeal.com      36
# Amazon.in, Flipkart.com, Myntra.com        15
# Flipkart.com                               15
# Flipkart.com, Myntra.com, Snapdeal.com     14
# Name: Speedy order delivery , dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Speedy order delivery ',data=df)

# %% [markdown]
# # AMAZON AND FLIPKART IS HAVING REMARKABLE REVIEW IN SPEED OF DELIVERY COMAPARED TO OTHERS.

# %% [markdown]
# # 58 COLUMN

# %%
df['Privacy of customers’ information'].value_counts()
# Out:
# Amazon.in                                                       71
# Amazon.in, Flipkart.com                                         54
# Amazon.in, Flipkart.com, Myntra.com                             25
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    24
# Paytm.com                                                       18
# Amazon.in, Paytm.com                                            15
# Myntra.com                                                      15
# Flipkart.com                                                    15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Amazon.in, Flipkart.com, Snapdeal.com                            7
# Name: Privacy of customers’ information, dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Privacy of customers’ information',data=df)

# %% [markdown]
# # ACCORDING TO THE DATA AMAZON AND FLIPKART SHOW CONCERN ABOUT Privacy of customers’ information.

# %% [markdown]
# # 59 COLUMN

# %%
df['Security of customer financial information'].value_counts()
# Out:
# Amazon.in                                                       51
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    42
# Flipkart.com                                                    33
# Amazon.in, Flipkart.com, Snapdeal.com                           25
# Amazon.in, Flipkart.com                                         24
# Amazon.in, Paytm.com, Myntra.com                                20
# Amazon.in, Snapdeal.com                                         19
# Paytm.com                                                       15
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               14
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Security of customer financial information, dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Security of customer financial information',data=df)

# %% [markdown]
# # AMAZON WIN THE COMPETION OF Security of customer financial information FROM OTHERS ACCORDING TO CUSTOMER REVIEWS.

# %% [markdown]
# # 60 COLUMN

# %%
df['Perceived Trustworthiness'].value_counts()
# Out:
# Amazon.in                                                       76
# Amazon.in, Flipkart.com, Snapdeal.com                           36
# Amazon.in, Myntra.com                                           35
# Amazon.in, Flipkart.com                                         31
# Flipkart.com                                                    27
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal.com               25
# Myntra.com                                                      15
# Amazon.in, Flipkart.com, Paytm.com, Myntra.com, Snapdeal.com    13
# Amazon.in, Flipkart.com, Paytm.com                              11
# Name: Perceived Trustworthiness, dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Perceived Trustworthiness',data=df)

# %% [markdown]
# # AMAZON IS HAVING HIGHEST PERCEVIED TURSTWORTHINESS FOLLOWED BY FLIPKART,SNAPDEAL,MYNTRA,ETC.

# %% [markdown]
# # 61 COLUMN

# %%
df['Presence of online assistance through multi-channel'].value_counts()
# Out:
# Amazon.in, Flipkart.com, Myntra.com, Snapdeal    61
# Amazon.in                                        60
# Amazon.in, Flipkart.com                          39
# Amazon.in, Snapdeal                              26
# Myntra.com                                       20
# Amazon.in, Flipkart.com, Myntra.com              15
# Amazon.in, Myntra.com                            15
# Amazon.in, Flipkart.com, Paytm.com               13
# Paytm.com                                        12
# Flipkart.com                                      8
# Name: Presence of online assistance through multi-channel, dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Presence of online assistance through multi-channel',data=df)

# %% [markdown]
# # AMAZON,FLIPKART,MYNTRA AND SNAPDEAL IS HAVING BETTER Presence of online assistance through multi-channel THAN OTHERS.

# %% [markdown]
# # 62 COLUMN

# %%
df['Longer time to get logged in (promotion, sales period)'].value_counts()
# Out:
# Amazon.in                                57
# Paytm.com                                38
# Amazon.in, Flipkart.com                  38
# Myntra.com                               35
# Amazon.in, Flipkart.com, Snapdeal.com    29
# Snapdeal.com                             25
# Flipkart.com, Paytm.com                  15
# Flipkart.com, Paytm.com, Snapdeal.com    13
# Amazon.in, Paytm.com                     11
# Flipkart.com                              8
# Name: Longer time to get logged in (promotion, sales period), dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Longer time to get logged in (promotion, sales period)',data=df)

# %% [markdown]
# # AMAZON AND FLIPKART TAKES Longer time to get logged in (promotion, sales period).

# %% [markdown]
# # 63 COLUMN

# %%
df['Longer time in displaying graphics and photos (promotion, sales period)'].value_counts()
# Out:
# Amazon.in, Flipkart.com                60
# Amazon.in                              39
# Myntra.com                             35
# Snapdeal.com                           34
# Myntra.com, Snapdeal.com               25
# Flipkart.com, Snapdeal.com             19
# Paytm.com                              15
# Flipkart.com                           15
# Amazon.in, Myntra.com, Snapdeal.com    14
# Amazon.in, Paytm.com                   13
# Name: Longer time in displaying graphics and photos (promotion, sales period), dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Longer time in displaying graphics and photos (promotion, sales period)',data=df)

# %% [markdown]
# # MOST OF THE CUSTOMER SAY'S THAT AMAZON TAKES Longer time in displaying graphics and photos (promotion, sales period).

# %% [markdown]
# # 64 COLUMN

# %%
df['Late declaration of price (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                 75
# Paytm.com                  52
# snapdeal.com               41
# Amazon.in                  38
# Flipkart.com               38
# Amazon.in, Paytm.com       13
# Paytm.com, snapdeal.com     7
# Amazon.in, Flipkart.com     5
# Name: Late declaration of price (promotion, sales period), dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Late declaration of price (promotion, sales period)',data=df)

# %% [markdown]
# # MYNTRA AND PAYTM DECLARE THE PRICE OF PRODUCT VERY LATE
# AMAZON IS THE BEST IN TERM OF DECLARATION OF PRICE OF PRODUCTS AT THE TIME OF PROMOTIN OR SALES

# %% [markdown]
# # 65 COLUMN

# %%
df['Longer page loading time (promotion, sales period)'].value_counts()
# Out:
# Myntra.com                          61
# Paytm.com                           59
# Flipkart.com                        32
# Snapdeal.com                        23
# Amazon.in, Flipkart.com             18
# Amazon.in                           16
# Paytm.com, Snapdeal.com             15
# Amazon.in, Snapdeal.com             14
# Amazon.in, Paytm.com                13
# Flipkart.com, Snapdeal.com          11
# Amazon.in, Paytm.com, Myntra.com     7
# Name: Longer page loading time (promotion, sales period), dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Longer page loading time (promotion, sales period)',data=df)

# %% [markdown]
# # PAYTM AND MYNTRA HAVE MAXIMUM LOADING TIME AS COMPARED TO OTHER WESITES

# %% [markdown]
# # 66 COLUMN

# %%
df['Limited mode of payment on most products (promotion, sales period)'].value_counts()
# Out:
# Snapdeal.com                87
# Amazon.in                   62
# Flipkart.com                31
# Amazon.in, Flipkart.com     29
# Paytm.com                   25
# Paytm.com, Snapdeal.com     15
# Amazon.in, Paytm.com        13
# Myntra.com, Snapdeal.com     7
# Name: Limited mode of payment on most products (promotion, sales period), dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Limited mode of payment on most products (promotion, sales period)',data=df)

# %% [markdown]
# # SNAPDEAL AND AMAZON HAVE LIMITED MODES OF PAYMENT ON MOST OF THE PRODUCTS

# %% [markdown]
# # 67 COLUMN

# %%
df['Longer delivery period'].value_counts()
# Out:
# Paytm.com                  72
# Snapdeal.com               64
# Flipkart.com               44
# Amazon.in                  37
# Paytm.com, Snapdeal.com    26
# Myntra.com                 26
# Name: Longer delivery period, dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Longer delivery period',data=df)

# %% [markdown]
# # Most of the people experience LONGER DELIVERY PERIOD IN SNAPDEAL AND PAYTM COMPANY

# %% [markdown]
# # 68 COLUMN

# %%
df['Change in website/Application design'].value_counts()
# Out:
# Amazon.in                   96
# Paytm.com                   63
# Amazon.in, Flipkart.com     45
# Myntra.com                  30
# Flipkart.com                20
# Snapdeal.com                 8
# Flipkart.com, Myntra.com     7
# Name: Change in website/Application design, dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Change in website/Application design',data=df)

# %% [markdown]
# # Mazority of people analyze there is change in website/application design of AMAZON WEBSITE/APPLICATION

# %% [markdown]
# # 69 COLUMN

# %%
df['Frequent disruption when moving from one page to another'].value_counts()
# Out:
# Amazon.in                     53
# Myntra.com                    52
# Snapdeal.com                  49
# Paytm.com                     39
# Flipkart.com                  26
# Amazon.in, Flipkart.com       25
# Myntra.com, Snapdeal.com      14
# Flipkart.com, Snapdeal.com    11
# Name: Frequent disruption when moving from one page to another, dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Frequent disruption when moving from one page to another',data=df)

# %% [markdown]
# # In AMAZON, MYNTRA AND SNAPDEAL peolple face Frequent disruption when moving from one page to another

# %% [markdown]
# # 70 COLUMN

# %%
df['Website is as efficient as before'].value_counts()
# Out:
# Amazon.in                             94
# Flipkart.com                          47
# Amazon.in, Flipkart.com               45
# Amazon.in, Flipkart.com, Paytm.com    25
# Amazon.in, Paytm.com                  18
# Paytm.com                             15
# Myntra.com, Snapdeal.com              14
# Snapdeal.com                          11
# Name: Website is as efficient as before, dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Website is as efficient as before',data=df)

# %% [markdown]
# # WELL analysis say's that AMAZON IS THE BEST WEBSITE. Around 80% say's AMAZON is as efficient as before.

# %% [markdown]
# # 71 COLUMN

# %%
df['Which of the Indian online retailer would you recommend to a friend?'].value_counts()
# Out:
# Amazon.in                                            79
# Amazon.in, Flipkart.com                              62
# Flipkart.com                                         39
# Amazon.in, Myntra.com                                30
# Amazon.in, Paytm.com, Myntra.com                     20
# Amazon.in, Flipkart.com, Myntra.com                  15
# Amazon.in, Paytm.com                                 13
# Flipkart.com, Paytm.com, Myntra.com, snapdeal.com    11
# Name: Which of the Indian online retailer would you recommend to a friend?, dtype: int64

# %%
plt.figure(figsize=(15,10))     #(column,row)
sns.countplot(y='Which of the Indian online retailer would you recommend to a friend?',data=df)

# %% [markdown]
# # Most of the people will recommend both AMAZON and FLIPKART

# %%
df_final = pd.get_dummies(df,columns=['1Gender of respondent'])

# %%
df_final.head()
# Out:
#   2 How old are you?  3 Which city do you shop online from?  \
# 0         31-40 years                                 Delhi
# 1         21-30 years                                 Delhi
# 2         21-30 years                         Greater Noida
# 3         21-30 years                               Karnal
# 4         21-30 years                            Bangalore
#
#    4 What is the Pin Code of where you shop online from?  \
# 0                                             110009
# 1                                             110030
# 2                                             201308
# 3                                             132001
# 4                                             530068
#
#   5 Since How Long You are Shopping Online ?  \
# 0                              Above 4 years
# 1                              Above 4 years
# 2                                  3-4 years
# 3                                  3-4 years
# 4                                  2-3 years
# ...

# %%
df_final.columns
# Out:
# Index(['2 How old are you? ', '3 Which city do you shop online from?',
#        '4 What is the Pin Code of where you shop online from?',
#        '5 Since How Long You are Shopping Online ?',
#        '6 How many times you have made an online purchase in the past 1 year?',
#        '7 How do you access the internet while shopping on-line?',
#        '8 Which device do you use to access the online shopping?',
#        '9 What is the screen size of your mobile device?\t\t\t\t\t\t                                        ',
#        '10 What is the operating system (OS) of your device?\t\t\t\t                                          ',
#        '11 What browser do you run on your device to access the website?\t\t\t                                                          ',
#        '12 Which channel did you follow to arrive at your favorite online store for the first time?                                                                   ',
# ...
